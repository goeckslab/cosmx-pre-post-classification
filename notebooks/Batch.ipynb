# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
import pandas as pd
from typing import List
from pathlib import Path
import os
from pycaret.classification import *

# %%
patients = ["patient_c", "patient_d"]
radius = 90

# %%
save_folder = Path(str(radius))

if not save_folder.exists():
    save_folder.mkdir(parents=True)

# %% [markdown]
# # Data Loader

# %%
def load_patient(patient: str) -> {}:
    data_path = Path("..","data", "mapped_data", f"{radius}")

    data_frames: dict = {}

    for root, dirs, files in os.walk(data_path):
        for file in files:

            if Path(file).suffix != ".csv":
                continue

            if patient not in file:
                continue

            print(file)

            data_frames[Path(file).stem] = pd.read_csv(Path(data_path, file))

    return data_frames

# %%
def load_files(patient_to_be_excluded: str) -> (pd.DataFrame, List):
    if not patient_to_be_excluded:
        raise ValueError("Patient to be excluded needs to be specified.")

    data_path = Path("..", "data", "mapped_data",  f"{radius}" )

    data_frames: [pd.DataFrame] = []
    loaded_files = []
    for root, dirs, files in os.walk(data_path):
        for file in files:

            if Path(file).suffix != ".csv":
                continue

            if patient_to_be_excluded in file:
                continue

            print(file)

            data_frames.append(pd.read_csv(Path(data_path, file)))
            loaded_files.append(file)

    data_frames = pd.concat(data_frames, axis=0)
    return data_frames, loaded_files

# %%
for patient in patients:

    train_set, _ = load_files(patient)
    test_sets: dict = load_patient(patient=patient)
    test_set = list(test_sets.values())
    test_set = pd.concat(test_set, axis=0)
    
    
    if "CellID" in train_set.columns:
        train_set.drop(columns=["CellID"])
    train_set = train_set.drop(columns=["Patient Id", "Sample Id", "MouseIgG1"])
    train_set.reset_index(drop=True, inplace=True)
   
    if "CellID" in test_set.columns:
        test_set.drop(columns=["CellID"])
    test_set = test_set.drop(columns=["Patient Id", "Sample Id", "MouseIgG1"])
    experiment = setup(data=train_set,test_data=test_set, target='Treatment', index=False)
    # Perform initial model comparison.
    best = compare_models()
    model_comparison_df = pull()
    #save model comparison
    excluded_patient_file_name: Path = Path(f"{patient}_excluded_model_performance.csv")
    if not excluded_patient_file_name.exists():
        model_comparison_df.to_csv(Path(save_folder,excluded_patient_file_name))

    # Predict on test set
    # Evaluate the model (this will show the performance metrics in PyCaret's UI)
    predictions = predict_model(best, data=test_set)
    metrics = pull()
    metrics.to_csv(Path(save_folder, f"{patient}_metrics.csv"))
# Out:
# patient_d_272840.csv
# patient_d_321920.csv
# patient_c_272830.csv
# patient_c_303148.csv
# <style type="text/css">
# #T_0f11a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0f11a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f11a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0f11a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f11a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f11a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0f11a_row0_col1" class="data row0 col1" >8854</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f11a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0f11a_row1_col1" class="data row1 col1" >Treatment</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f11a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0f11a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f11a_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_0f11a_row3_col1" class="data row3 col1" >ON: 0, PRE: 1</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f11a_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_0f11a_row4_col1" class="data row4 col1" >(153144, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0f11a_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_0f11a_row5_col1" class="data row5 col1" >(153144, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0f11a_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_0f11a_row6_col1" class="data row6 col1" >(51732, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0f11a_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_0f11a_row7_col1" class="data row7 col1" >(101412, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0f11a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0f11a_row8_col1" class="data row8 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0f11a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0f11a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0f11a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0f11a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0f11a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0f11a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0f11a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0f11a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0f11a_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_0f11a_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0f11a_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_0f11a_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0f11a_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_0f11a_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0f11a_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_0f11a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0f11a_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_0f11a_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0f11a_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_0f11a_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0f11a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0f11a_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_0f11a_row19_col1" class="data row19 col1" >729d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_
row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3630a_row5_col1" class="data row5 col1" >0.9793</td>
#       <td id="T_3630a_row5_col2" class="data row5 col2" >0.9946</td>
#       <td id="T_3630a_row5_col3" class="data row5 col3" >0.9793</td>
#       <td id="T_3630a_row5_col4" class="data row5 col4" >0.9843</td>
#       <td id="T_3630a_row5_col5" class="data row5 col5" >0.9786</td>
#       <td id="T_3630a_row5_col6" class="data row5 col6" >0.9225</td>
#       <td id="T_3630a_row5_col7" class="data row5 col7" >0.9323</td>
# <style type="text/css">
# </style>
# <table id="T_931cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_931cd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_931cd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_931cd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_931cd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_931cd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_931cd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_931cd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_931cd_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_931cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_931cd_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_931cd_row0_col1" class="data row0 col1" >0.4899</td>
#       <td id="T_931cd_row0_col2" class="data row0 col2" >0.4969</td>
#       <td id="T_931cd_row0_col3" class="data row0 col3" >0.4899</td>
#       <td id="T_931cd_row0_col4" class="data row0 col4" >0.4946</td>
#       <td id="T_931cd_row0_col5" class="data row0 col5" >0.3892</td>
#       <td id="T_931cd_row0_col6" class="data row0 col6" >-0.0036</td>
#       <td id="T_931cd_row0_col7" class="data row0 col7" >-0.0063</td>
#     </tr>
#   </tbody>
# </table>
# patient_c_272830.csv
# patient_c_303148.csv
# patient_d_272840.csv
# patient_d_321920.csv
# <style type="text/css">
# #T_02e9f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_02e9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02e9f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_02e9f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02e9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02e9f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_02e9f_row0_col1" class="data row0 col1" >8964</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02e9f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_02e9f_row1_col1" class="data row1 col1" >Treatment</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02e9f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_02e9f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02e9f_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_02e9f_row3_col1" class="data row3 col1" >ON: 0, PRE: 1</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_02e9f_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_02e9f_row4_col1" class="data row4 col1" >(120482, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_02e9f_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_02e9f_row5_col1" class="data row5 col1" >(120482, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_02e9f_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_02e9f_row6_col1" class="data row6 col1" >(51740, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_02e9f_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_02e9f_row7_col1" class="data row7 col1" >(68742, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_02e9f_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_02e9f_row8_col1" class="data row8 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_02e9f_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_02e9f_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_02e9f_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_02e9f_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_02e9f_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_02e9f_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_02e9f_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_02e9f_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_02e9f_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_02e9f_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_02e9f_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_02e9f_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_02e9f_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_02e9f_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_02e9f_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_02e9f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_02e9f_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_02e9f_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_02e9f_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_02e9f_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_02e9f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_02e9f_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_02e9f_row19_col1" class="data row19 col1" >ef4d</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_586cb th {
#   text-align: left;
# }
# #T_586cb_row0_col0, #T_586cb_row0_col2, #T_586cb_row1_col0, #T_586cb_row1_col1, #T_586cb_row1_col3, #T_586cb_row1_col4, #T_586cb_row1_col5, #T_586cb_row1_col6, #T_586cb_row1_col7, #T_586cb_row2_col0, #T_586cb_row2_col1, #T_586cb_row2_col2, #T_586cb_row2_col3, #T_586cb_row2_col4, #T_586cb_row2_col5, #T_586cb_row2_col6, #T_586cb_row2_col7, #T_586cb_row3_col0, #T_586cb_row3_col1, #T_586cb_row3_col2, #T_586cb_row3_col3, #T_586cb_row3_col4, #T_586cb_row3_col5, #T_586cb_row3_col6, #T_586cb_row3_col7, #T_586cb_row4_col0, #T_586cb_row4_col1, #T_586cb_row4_col2, #T_586cb_row4_col3, #T_586cb_row4_col4, #T_586cb_row4_col5, #T_586cb_row4_col6, #T_586cb_row4_col7, #T_586cb_row5_col0, #T_586cb_row5_col1, #T_586cb_row5_col2, #T_586cb_row5_col3, #T_586cb_row5_col4, #T_586cb_row5_col5, #T_586cb_row5_col6, #T_586cb_row5_col7, #T_586cb_row6_col0, #T_586cb_row6_col1, #T_586cb_row6_col2, #T_586cb_row6_col3, #T_586cb_row6_col4, #T_586cb_row6_col5, #T_586cb_row6_col6, #T_586cb_row6_col7, #T_586cb_row7_col0, #T_586cb_row7_col1, #T_586cb_row7_col2, #T_586cb_row7_col3, #T_586cb_row7_col4, #T_586cb_row7_col5, #T_586cb_row7_col6, #T_586cb_row7_col7, #T_586cb_row8_col0, #T_586cb_row8_col1, #T_586cb_row8_col2, #T_586cb_row8_col3, #T_586cb_row8_col4, #T_586cb_row8_col5, #T_586cb_row8_col6, #T_586cb_row8_col7, #T_586cb_row9_col0, #T_586cb_row9_col1, #T_586cb_row9_col2, #T_586cb_row9_col3, #T_586cb_row9_col4, #T_586cb_row9_col5, #T_586cb_row9_col6, #T_586cb_row9_col7, #T_586cb_row10_col0, #T_586cb_row10_col1, #T_586cb_row10_col2, #T_586cb_row10_col3, #T_586cb_row10_col4, #T_586cb_row10_col5, #T_586cb_row10_col6, #T_586cb_row10_col7, #T_586cb_row11_col0, #T_586cb_row11_col1, #T_586cb_row11_col2, #T_586cb_row11_col3, #T_586cb_row11_col4, #T_586cb_row11_col5, #T_586cb_row11_col6, #T_586cb_row11_col7, #T_586cb_row12_col0, #T_586cb_row12_col1, #T_586cb_row12_col2, #T_586cb_row12_col3, #T_586cb_row12_col4, #T_586cb_row12_col5, #T_586cb_row12_col6, #T_586cb_row12_col7, #T_586cb_row13_col0, #T_586cb_row13_col1, #T_586cb_row13_col2, #T_586cb_row13_col3, #T_586cb_row13_col4, #T_586cb_row13_col5, #T_586cb_row13_col6, #T_586cb_row13_col7 {
#   text-align: left;
# }
# #T_586cb_row0_col1, #T_586cb_row0_col3, #T_586cb_row0_col4, #T_586cb_row0_col5, #T_586cb_row0_col6, #T_586cb_row0_col7, #T_586cb_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_586cb_row0_col8, #T_586cb_row1_col8, #T_586cb_row2_col8, #T_586cb_row3_col8, #T_586cb_row4_col8, #T_586cb_row5_col8, #T_586cb_row6_col8, #T_586cb_row7_col8, #T_586cb_row8_col8, #T_586cb_row10_col8, #T_586cb_row11_col8, #T_586cb_row12_col8, #T_586cb_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_586cb_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_586cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_586cb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_586cb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_586cb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_586cb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_586cb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_586cb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_586cb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_586cb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_586cb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_586cb_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_586cb_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_586cb_row0_col1" class="data row0 col1" >0.9830</td>
#       <td id="T_586cb_row0_col2" class="data row0 col2" >0.9902</td>
#       <td id="T_586cb_row0_col3" class="data row0 col3" >0.9830</td>
#       <td id="T_586cb_row0_col4" class="data row0 col4" >0.9838</td>
#       <td id="T_586cb_row0_col5" class="data row0 col5" >0.9830</td>
#       <td id="T_586cb_row0_col6" class="data row0 col6" >0.9661</td>
#       <td id="T_586cb_row0_col7" class="data row0 col7" >0.9668</td>
#       <td id="T_586cb_row0_col8" class="data row0 col8" >2.4570</td>
#     </tr>
#     <tr>
#       <th id="T_586cb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_586cb_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_586cb_row1_col1" class="data row1 col1" >0.9817</td>
#       <td id="T_586cb_row1_col2" class="data row1 col2" >0.9958</td>
#       <td id="T_586cb_row1_col3" class="data row1 col3" >0.9817</td>
#       <td id="T_586cb_row1_col4" class="data row1 col4" >0.9819</td>
#       <td id="T_586cb_row1_col5" class="data row1 col5" >0.9817</td>
#       <td id="T_586cb_row1_col6" class="data row1 col6" >0.9633</td>
#       <td id="T_586cb_row1_col7" class="data row1 col7" >0.9635</td>
#       <td id="T_586cb_row1_col8" class="data row1 col8" >0.6090</td>
#     </tr>
#     <tr>
#       <th id="T_586cb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_586cb_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_586cb_row2_col1" class="data row2 col1" >0.9764</td>
#       <td id="T_586cb_row2_col2" class="data row2 col2" >0.9937</td>
#       <td id="T_586cb_row2_col3" class="data row2 col3" >0.9764</td>
#       <td id="T_586cb_row2_col4" class="data row2 col4" >0.9769</td>
#       <td id="T_586cb_row2_col5" class="data row2 col5" >0.9764</td>
#       <td id="T_586cb_row2_col6" class="data row2 col6" >0.9527</td>
#       <td id="T_586cb_row2_col7" class="data row2 col7" >0.9532</td>
#       <td id="T_586cb_row2_col8" class="data row2 col8" >3.9300</td>
#     </tr>
#     <tr>
#       <th id="T_586cb_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_586cb_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_586cb_row3_col1" class="data row3 col1" >0.9760</td>
#       <td id="T_586cb_row3_col2" class="data row3 col2" >0.9933</td>
#       <td id="T_586cb_row3_col3" class="data row3 col3" >0.9760</td>
#       <td id="T_586cb_row3_col4" class="data row3 col4" >0.9764</td>
#       <td id="T_586cb_row3_col5" class="data row3 col5" >0.9759</td>
#       <td id="T_586cb_row3_col6" class="data row3 col6" >0.9518</td>
#       <td id="T_586cb_row3_col7" class="data row3 col7" >0.9523</td>
#       <td id="T_586cb_row3_col8" class="data row3 col8" >13.5970</td>
#     </tr>
#     <tr>
#       <th id="T_586cb_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_586cb_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_586cb_row4_col1" class="data row4 col1" >0.9734</td>
#       <td id="T_586cb_row4_col2" class="data row4 col2" >0.9917</td>
#       <td id="T_586cb_row4_col3" class="data row4 col3" >0.9734</td>
#       <td id="T_586cb_row4_col4" class="data row4 col4" >0.9740</td>
#       <td id="T_586cb_row4_col5" class="data row4 col5" >0.9734</td>
#       <td id="T_586cb_row4_col6" class="data row4 col6" >0.9468</td>
#       <td id="T_586cb_row4_col7" class="data row4 col7" >0.9474</td>
#       <td id="T_586cb_row4_col8" class="data row4 col8" >1.5870</td>
#     </tr>
#     <tr>
#       <th id="T_586cb_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_586cb_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_586cb_row5_col1" class="data row5 col1" >0.9723</td>
#       <td id="T_586cb_row5_col2" class="data row5 col2" >0.9886</td>
#       <td id="T_586cb_row5_col3" class="data row5 col3" >0.9723</td>
#       <td id="T_586cb_row5_col4" class="data row5 col4" >0.9734</td>
#       <td id="T_586cb_row5_col5" class="data row5 col5" >0.9722</td>
#       <td id="T_586cb_row5_col6" class="data row5 col6" >0.9447</td>
#       <td id="T_586cb_row5_col7" class="data row5 col7" >0.9457</td>
# <style type="text/css">
# </style>
# <table id="T_67733">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67733_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_67733_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_67733_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_67733_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_67733_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_67733_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_67733_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_67733_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67733_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67733_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_67733_row0_col1" class="data row0 col1" >0.2486</td>
#       <td id="T_67733_row0_col2" class="data row0 col2" >0.5470</td>
#       <td id="T_67733_row0_col3" class="data row0 col3" >0.2486</td>
#       <td id="T_67733_row0_col4" class="data row0 col4" >0.4510</td>
#       <td id="T_67733_row0_col5" class="data row0 col5" >0.1243</td>
#       <td id="T_67733_row0_col6" class="data row0 col6" >-0.0186</td>
#       <td id="T_67733_row0_col7" class="data row0 col7" >-0.0939</td>
#     </tr>
#   </tbody>
# </table>
