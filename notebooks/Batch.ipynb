# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
import pandas as pd
from typing import List
from pathlib import Path
import os
from pycaret.classification import *

# %%
patients = ["patient_c", "patient_d"]
radius = 120

# %%
save_folder = Path(str(radius))

if not save_folder.exists():
    save_folder.mkdir(parents=True)

# %% [markdown]
# # Data Loader

# %%
def load_patient(patient: str) -> {}:
    data_path = Path("..","data", "mapped_data", f"{radius}")

    data_frames: dict = {}

    for root, dirs, files in os.walk(data_path):
        for file in files:

            if Path(file).suffix != ".csv":
                continue

            if patient not in file:
                continue

            print(file)

            data_frames[Path(file).stem] = pd.read_csv(Path(data_path, file))

    return data_frames

# %%
def load_files(patient_to_be_excluded: str) -> (pd.DataFrame, List):
    if not patient_to_be_excluded:
        raise ValueError("Patient to be excluded needs to be specified.")

    data_path = Path("..", "data", "mapped_data",  f"{radius}" )

    data_frames: [pd.DataFrame] = []
    loaded_files = []
    for root, dirs, files in os.walk(data_path):
        for file in files:

            if Path(file).suffix != ".csv":
                continue

            if patient_to_be_excluded in file:
                continue

            print(file)

            data_frames.append(pd.read_csv(Path(data_path, file)))
            loaded_files.append(file)

    data_frames = pd.concat(data_frames, axis=0)
    return data_frames, loaded_files

# %%
for patient in patients:
    print(patient)
    train_set, _ = load_files(patient)
    test_sets: dict = load_patient(patient=patient)
    test_set = list(test_sets.values())
    test_set = pd.concat(test_set, axis=0)
    
    
    if "CellID" in train_set.columns:
        train_set.drop(columns=["CellID"])
    train_set = train_set.drop(columns=["Patient Id", "Sample Id", "MouseIgG1"])
    train_set.reset_index(drop=True, inplace=True)
   
    if "CellID" in test_set.columns:
        test_set.drop(columns=["CellID"])
    test_set = test_set.drop(columns=["Patient Id", "Sample Id", "MouseIgG1"])
    experiment = setup(data=train_set,test_data=test_set, target='Treatment', index=False)
    # Perform initial model comparison.
    best = compare_models()
    model_comparison_df = pull()
    #save model comparison
    excluded_patient_file_name: Path = Path(f"{patient}_excluded_model_performance.csv")
    if not excluded_patient_file_name.exists():
        model_comparison_df.to_csv(Path(save_folder,excluded_patient_file_name))

    # Predict on test set
    holdout_pred = predict_model(best)
    holdout_pred.to_csv(Path(save_folder, f"{file_name}_results.csv"))
# Out:
# patient_c
# patient_d_272840.csv
# patient_d_321920.csv
# patient_c_272830.csv
# patient_c_303148.csv
# <style type="text/css">
# #T_cd6fc_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cd6fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd6fc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cd6fc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd6fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd6fc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cd6fc_row0_col1" class="data row0 col1" >1498</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd6fc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cd6fc_row1_col1" class="data row1 col1" >Treatment</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd6fc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cd6fc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd6fc_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_cd6fc_row3_col1" class="data row3 col1" >ON: 0, PRE: 1</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd6fc_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_cd6fc_row4_col1" class="data row4 col1" >(153144, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cd6fc_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_cd6fc_row5_col1" class="data row5 col1" >(153144, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cd6fc_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_cd6fc_row6_col1" class="data row6 col1" >(51732, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cd6fc_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_cd6fc_row7_col1" class="data row7 col1" >(101412, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cd6fc_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_cd6fc_row8_col1" class="data row8 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cd6fc_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_cd6fc_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cd6fc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cd6fc_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_cd6fc_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c
td>
#     </tr>
#     <tr>
#       <th id="T_9f0ea_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_9f0ea_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_9f0ea_row3_col1" class="data row3 col1" >0.9849</td>
#       <td id="T_9f0ea_row3_col2" class="data row3 col2" >0.9993</td>
#       <td id="T_9f0ea_row3_col3" class="data row3 col3" >0.9849</td>
#       <td id="T_9f0ea_row3_col4" class="data row3 col4" >0.9872</td>
#       <td id="T_9f0ea_row3_col5" class="data row3 col5" >0.9843</td>
#       <td id="T_9f0ea_row3_col6" class="data row3 col6" >0.9413</td>
#       <td id="T_9f0ea_row3_col7" class="data row3 col7" >0.9472</td>
#       <td id="T_9f0ea_row3_col8" class="data row3 col8" >4.3830</td>
#     </tr>
#     <tr>
#       <th id="T_9f0ea_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_9f0ea_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_9f0ea_row4_col1" class="data row4 col1" >0.9830</td>
#       <td id="T_9f0ea_row4_col2" class="data row4 col2" >0.9948</td>
#       <td id="T_9f0ea_row4_col3" class="data row4 col3" >0.9830</td>
#       <td id="T_9f0ea_row4_col4" class="data row4 col4" >0.9854</td>
#       <td id="T_9f0ea_row4_col5" class="data row4 col5" >0.9814</td>
#       <td id="T_9f0ea_row4_col6" class="data row4 col6" >0.9286</td>
#       <td id="T_9f0ea_row4_col7" class="data row4 col7" >0.9373</td>
#       <td id="T_9f0ea_row4_col8" class="data row4 col8" >3.2150</td>
#     </tr>
#     <tr>
#       <th id="T_9f0ea_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_9f0ea_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9f0ea_row5_col1" class="data row5 col1" >0.9830</td>
#       <td id="T_9f0ea_row5_col2" class="data row5 col2" >0.9930</td>
#       <td id="T_9f0ea_row5_col3" class="data row5 col3" >0.9830</td>
#       <td id="T_9f0ea_row5_col4" class="data row5 col4" >0.9856</td>
#       <td id="T_9f0ea_row5_col5" class="data row5 col5" >0.9815</td>
#       <td id="T_9f0ea_row5_col6" class="data row5 col6" >0.9296</td>
#       <td id="T_9f0ea_row5_col7" class="data row5 col7" >0.9382</td>
# <style type="text/css">
# </style>
# <table id="T_1ced7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ced7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1ced7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1ced7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1ced7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1ced7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1ced7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1ced7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1ced7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ced7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ced7_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_1ced7_row0_col1" class="data row0 col1" >0.4898</td>
#       <td id="T_1ced7_row0_col2" class="data row0 col2" >0.4940</td>
#       <td id="T_1ced7_row0_col3" class="data row0 col3" >0.4898</td>
#       <td id="T_1ced7_row0_col4" class="data row0 col4" >0.4944</td>
#       <td id="T_1ced7_row0_col5" class="data row0 col5" >0.3974</td>
#       <td id="T_1ced7_row0_col6" class="data row0 col6" >-0.0043</td>
#       <td id="T_1ced7_row0_col7" class="data row0 col7" >-0.0070</td>
#     </tr>
#   </tbody>
# </table>
# patient_d
# patient_c_272830.csv
# patient_c_303148.csv
# patient_d_272840.csv
# patient_d_321920.csv
# <style type="text/css">
# #T_ac3db_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ac3db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac3db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ac3db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac3db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac3db_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ac3db_row0_col1" class="data row0 col1" >8924</td>
#     </tr>
#     <tr>
#       <th id="T_ac3db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac3db_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ac3db_row1_col1" class="data row1 col1" >Treatment</td>
#     </tr>
#     <tr>
#       <th id="T_ac3db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac3db_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ac3db_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ac3db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac3db_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_ac3db_row3_col1" class="data row3 col1" >ON: 0, PRE: 1</td>
#     </tr>
#     <tr>
#       <th id="T_ac3db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac3db_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ac3db_row4_col1" class="data row4 col1" >(120482, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_
7bb_row10_col7, #T_ea7bb_row11_col0, #T_ea7bb_row11_col1, #T_ea7bb_row11_col2, #T_ea7bb_row11_col3, #T_ea7bb_row11_col4, #T_ea7bb_row11_col5, #T_ea7bb_row11_col6, #T_ea7bb_row11_col7, #T_ea7bb_row12_col0, #T_ea7bb_row12_col1, #T_ea7bb_row12_col2, #T_ea7bb_row12_col3, #T_ea7bb_row12_col4, #T_ea7bb_row12_col5, #T_ea7bb_row12_col6, #T_ea7bb_row12_col7, #T_ea7bb_row13_col0, #T_ea7bb_row13_col1, #T_ea7bb_row13_col2, #T_ea7bb_row13_col3, #T_ea7bb_row13_col4, #T_ea7bb_row13_col5, #T_ea7bb_row13_col6, #T_ea7bb_row13_col7 {
#   text-align: left;
# }
# #T_ea7bb_row0_col1, #T_ea7bb_row0_col3, #T_ea7bb_row0_col4, #T_ea7bb_row0_col5, #T_ea7bb_row0_col6, #T_ea7bb_row0_col7, #T_ea7bb_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ea7bb_row0_col8, #T_ea7bb_row1_col8, #T_ea7bb_row2_col8, #T_ea7bb_row3_col8, #T_ea7bb_row4_col8, #T_ea7bb_row5_col8, #T_ea7bb_row6_col8, #T_ea7bb_row7_col8, #T_ea7bb_row8_col8, #T_ea7bb_row9_col8, #T_ea7bb_row10_col8, #T_ea7bb_row11_col8, #T_ea7bb_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ea7bb_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ea7bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea7bb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea7bb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ea7bb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ea7bb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ea7bb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ea7bb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ea7bb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ea7bb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ea7bb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea7bb_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_ea7bb_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_ea7bb_row0_col1" class="data row0 col1" >0.9845</td>
#       <td id="T_ea7bb_row0_col2" class="data row0 col2" >0.9892</td>
#       <td id="T_ea7bb_row0_col3" class="data row0 col3" >0.9845</td>
#       <td id="T_ea7bb_row0_col4" class="data row0 col4" >0.9854</td>
#       <td id="T_ea7bb_row0_col5" class="data row0 col5" >0.9845</td>
#       <td id="T_ea7bb_row0_col6" class="data row0 col6" >0.9691</td>
#       <td id="T_ea7bb_row0_col7" class="data row0 col7" >0.9699</td>
#       <td id="T_ea7bb_row0_col8" class="data row0 col8" >2.6780</td>
#     </tr>
#     <tr>
#       <th id="T_ea7bb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_ea7bb_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_ea7bb_row1_col1" class="data row1 col1" >0.9826</td>
#       <td id="T_ea7bb_row1_col2" class="data row1 col2" >0.9962</td>
#       <td id="T_ea7bb_row1_col3" class="data row1 col3" >0.9826</td>
#       <td id="T_ea7bb_row1_col4" class="data row1 col4" >0.9828</td>
#       <td id="T_ea7bb_row1_col5" class="data row1 col5" >0.9826</td>
#       <td id="T_ea7bb_row1_col6" class="data row1 col6" >0.9652</td>
#       <td id="T_ea7bb_row1_col7" class="data row1 col7" >0.9654</td>
#       <td id="T_ea7bb_row1_col8" class="data row1 col8" >0.6360</td>
#     </tr>
#     <tr>
#       <th id="T_ea7bb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ea7bb_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T